# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\vruti\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.8/40.2 MB 5.1 MB/s eta 0:00:08
#    -- ------------------------------------- 2.9/40.2 MB 8.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.2/40.2 MB 9.8 MB/s eta 0:00:04
#    ------- -------------------------------- 7.6/40.2 MB 10.3 MB/s eta 0:00:04
#    --------- ------------------------------ 9.4/40.2 MB 10.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.5/40.2 MB 10.0 MB/s eta 0:00:03
#    ------------- -------------------------- 13.4/40.2 MB 9.9 MB/s eta 0:00:03
#    --------------- ------------------------ 15.7/40.2 MB 10.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 18.1/40.2 MB 10.1 MB/s eta 0:00:03
#    -------------------- ------------------- 20.4/40.2 MB 10.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 23.1/40.2 MB 10.4 MB/s eta 0:00:02
#    ------------------------- -------------- 25.2/40.2 MB 10.4 MB/s eta 0:00:02
#    --------------------------- ------------ 27.8/40.2 MB 10.5 MB/s eta 0:00:02
#    ------------------------------ --------- 30.4/40.2 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 33.3/40.2 MB 10.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 35.7/40.2 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 38.0/40.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/40.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 9.5 MB/s  0:00:04
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
haarcascade_frontalface_default.xml
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 haarcascade_frontalface_default.xml
#
# NameError: name 'haarcascade_frontalface_default' is not defined

# %%
import cv2
import matplotlib.pyplot as plt

# Load the Haar Cascade model
face_cascade = cv2.CascadeClassifier("C:/Codesoft/haarcascade_frontalface_default.xml")

# Read the image
img = cv2.imread("C:/Codesoft/matthew_perry.jpg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# Draw rectangle around face
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0,255,0), 3)

# Show image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 11
#       8 img = cv2.imread("C:/Codesoft/matthew_perry.jpg")
#      10 # Convert to grayscale
# ---> 11 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      13 # Detect faces
#      14 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
