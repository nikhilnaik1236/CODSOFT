# %%
# !pip install tensorflow numpy pillow

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Vruti

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image
import numpy as np

# Load pre-trained ResNet model
model = ResNet50(weights='imagenet')

# Function to extract image features
def extract_features(img_path):
    img = image.load_img(img_path, target_size=(224,224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    features = model.predict(img_array)
    return features

# Caption generator (simple demo caption)
def generate_caption(features):
    caption = "A futuristic representation of a human brain interacting with artificial intelligence."
    return caption

# Image path
img_path = "C:/Codesoft/ai_brain_robot.jpg"

# Extract image features
features = extract_features(img_path)

# Generate caption
caption = generate_caption(features)

print("Generated Caption:")
print(caption)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# Generated Caption:
# A futuristic representation of a human brain interacting with artificial intelligence.

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("C:/Codesoft/ai_brain_robot.jpg")

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1279.5), np.float64(719.5), np.float64(-0.5))
